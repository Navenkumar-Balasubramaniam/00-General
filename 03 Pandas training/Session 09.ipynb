# %% [markdown]
# # Session 09
#
# [![Open and Execute in Google Colaboratory](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/astrojuanlu/ie-mbd-python-data-analysis-i/blob/main/sessions/Session%2009.ipynb)
#
# - Tabular data with pandas DataFrames
# - Slicing and indexing pandas DataFrames
# - Filtering pandas DataFrames
# - 1-dimensional data: pandas Series

# %% [markdown]
# ## Tabular data with pandas `DataFrame`s

# %% [markdown]
# pandas is the most widely used Python library to read and manipulate tabular data. Its most important object is the `DataFrame`, which represents a rectangular table of rows and columns.
#
# To start using pandas, you need to import it first. The most common way to import pandas is this:

# %%
import pandas as pd

# %% [markdown]
# All the pandas functions will be accessible under the `pd` alias:

# %%
pd.__version__
# Out:
# '2.2.2'

# %% [markdown]
# `DataFrame` objects are rectangular tables formed by a number of columns. Each column can have a different `dtype`, but all of them must have the same number of rows.
#
# `DataFrame` objects can be created with the `DataFrame()` initializer, but in most cases they will appear as a result of other function or method calls, for example `pandas.read_csv`:

# %%
df = pd.read_csv(
    "https://github.com/astrojuanlu/ie-mbd-python-data-analysis-i/"
    "raw/main/data/titanic.csv"
)
# df = pd.read_csv("national_covid19.csv", index_col="date")  # You can specify the index column

# %% [markdown]
# It's a good practice to display the first few rows of the `DataFrame` right after opening it:

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %% [markdown]
# Notice that you can retrieve the `dtypes` of the `DataFrame` (it's no longer a single `dtype`!) as well as a few other important properties:

# %% [markdown]
# --(important)Learn which are properties and which are methods

# %%
df.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %% [markdown]
# --(important) most of the time object tends to be string but it could also be different

# %%
df.shape
# Out:
# (891, 12)

# %% [markdown]
# Some clarifications:
#
# - The `object` dtype means something pandas couldn't parse. Could be a string, a string representing a date, or something completely different. In most cases it means `str`, but be careful when they appear.
# - `float64` is similar to `int64`: a floating point value with 64 bits of precision.
# - `NaN` means "Not a Number" and in general it means "missing value". In following sessions you will see how to effectively handle missing values, and what do they mean.

# %% [markdown]
# `DataFrame` objects have a large number of methods as well:

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %% [markdown]
# Notice that `object` columns are excluded. To include them all:

# %%
df.describe(include="all")
# Out:
#         PassengerId    Survived      Pclass                 Name   Sex  \
# count    891.000000  891.000000  891.000000                  891   891
# unique          NaN         NaN         NaN                  891     2
# top             NaN         NaN         NaN  Dooley, Mr. Patrick  male
# freq            NaN         NaN         NaN                    1   577
# mean     446.000000    0.383838    2.308642                  NaN   NaN
# std      257.353842    0.486592    0.836071                  NaN   NaN
# min        1.000000    0.000000    1.000000                  NaN   NaN
# 25%      223.500000    0.000000    2.000000                  NaN   NaN
# 50%      446.000000    0.000000    3.000000                  NaN   NaN
# 75%      668.500000    1.000000    3.000000                  NaN   NaN
# max      891.000000    1.000000    3.000000                  NaN   NaN
#
#                Age       SibSp       Parch  Ticket        Fare Cabin Embarked
# count   714.000000  891.000000  891.000000     891  891.000000   204      889
# unique         NaN         NaN         NaN     681         NaN   147        3
# top            NaN         NaN         NaN  347082         NaN    G6        S
# freq           NaN         NaN         NaN       7         NaN     4      644
# mean     29.699118    0.523008    0.381594     NaN   32.204208   NaN      NaN
# std      14.526497    1.102743    0.806057     NaN   49.693429   NaN      NaN
# min       0.420000    0.000000    0.000000     NaN    0.000000   NaN      NaN
# 25%      20.125000    0.000000    0.000000     NaN    7.910400   NaN      NaN
# 50%      28.000000    0.000000    0.000000     NaN   14.454200   NaN      NaN
# 75%      38.000000    1.000000    0.000000     NaN   31.000000   NaN      NaN
# max      80.000000    8.000000    6.000000     NaN  512.329200   NaN      NaN

# %% [markdown]
# ## Exercises
#
# ### 1. CSV reading
#
# Read the `grandes-tenedores-madrid.csv` file and display
# - number of rows,
# - number of columns,
# - dtypes of the columns,
# - and the first five rows
#
# Tip: The path is `https://github.com/astrojuanlu/ie-mbd-python-data-analysis-i/raw/main/data/grandes-tenedores-madrid.csv`
#
# Data source: https://datos.civio.es/dataset/megatenedores-de-la-comunidad-de-madrid/

# %%
import pandas as pd
df_gtm = pd.read_csv("https://github.com/astrojuanlu/ie-mbd-python-data-analysis-i/raw/main/data/grandes-tenedores-madrid.csv")

# %%
df_gtm.shape
# Out:
# (463, 19)

# %%
nrows, ncols = df_gtm.shape
nrows
# Out:
# 463

# %%
df_gtm.head()
# Out:
#          NIF      Filial propietaria directa  Inmuebles         Matriz  \
# 0  A70302039  ABANCA CORPORACION BANCARIA SA         55         Abanca
# 1  B09658576       ACEF SPAIN PROPCO, S.L.U.        523            Axa
# 2  B31813843         ADANIA PATRIMONIO, S.L.        148         Adania
# 3  Q2802152E             ADIF-ALTA VELOCIDAD        142           Adif
# 4  B83195800                  ADMAFINCAS S.L         88  Admafincas SL
#
#   Sede empresa matriz Sociedad intermedia utilizada Sede sociedad utilizada  \
# 0              España                        Abanca                  España
# 1             Francia            Acef Holding S.C.A              Luxemburgo
# 2              España                        Adania                  España
# 3              España                          Adif                  España
# 4              España                 Admafincas SL                  España
#
#                 Tipo sociedad utilizada          Administración  \
# 0                       Empresa privada                     NaN
# 1                                Socimi                     NaN
# 2                       Empresa privada                     NaN
# 3  Empresas públicas o administraciones  Administración central
# 4                       Empresa privada                     NaN
#
#                   Sector                        Subsector  \
# 0  Entidades financieras                            Banca
# 1                Seguros                              NaN
# 2           Inmobiliaria                              NaN
# 3                  Otros  Infraestructuras aeroportuarias
# 4           Inmobiliaria                              NaN
#
#                                               Fuente  \
# 0  https://civio.box.com/s/66p5k4lv0dr7ox37wzvnlk...
# 1  https://www.boe.es/borme/dias/2022/04/08/pdfs/...
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                             Fuente 2  \
# 0                                                NaN
# 1  https://www.boe.es/borme/dias/2022/04/07/pdfs/...
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                             Fuente 3 Fuente 4 Fuente 5  \
# 0                                                NaN      NaN      NaN
# 1  https://www.boe.es/borme/dias/2022/05/06/pdfs/...      NaN      NaN
# 2                                                NaN      NaN      NaN
# 3                                                NaN      NaN      NaN
# 4                                                NaN      NaN      NaN
#
#   Fuente 6 Fuente 7 Fuente 8
# 0      NaN      NaN      NaN
# 1      NaN      NaN      NaN
# 2      NaN      NaN      NaN
# 3      NaN      NaN      NaN
# 4      NaN      NaN      NaN

# %%
df_gtm.describe()
# Out:
#           Inmuebles
# count    463.000000
# mean     256.714903
# std     1110.339019
# min       50.000000
# 25%       64.000000
# 50%       95.000000
# 75%      179.000000
# max    21445.000000

# %%
df_gtm.describe(include='all')
# Out:
#               NIF Filial propietaria directa     Inmuebles      Matriz  \
# count         463                        463    463.000000         463
# unique        463                        463           NaN         373
# top     E81064826        ZAZO HERMANOS, C.B.           NaN  Blackstone
# freq            1                          1           NaN          19
# mean          NaN                        NaN    256.714903         NaN
# std           NaN                        NaN   1110.339019         NaN
# min           NaN                        NaN     50.000000         NaN
# 25%           NaN                        NaN     64.000000         NaN
# 50%           NaN                        NaN     95.000000         NaN
# 75%           NaN                        NaN    179.000000         NaN
# max           NaN                        NaN  21445.000000         NaN
#
#        Sede empresa matriz           Sociedad intermedia utilizada  \
# count                  463                                     463
# unique                  13                                     400
# top                 España  Spanish Residential (Reit) Holdco SARL
# freq                   385                                      14
# mean                   NaN                                     NaN
# std                    NaN                                     NaN
# min                    NaN                                     NaN
# 25%                    NaN                                     NaN
# 50%                    NaN                                     NaN
# 75%                    NaN                                     NaN
# max                    NaN                                     NaN
#
#        Sede sociedad utilizada Tipo sociedad utilizada Administración  \
# count                      463                     463             27
# unique                      12                       9              4
# top                     España         Empresa privada   Ayuntamiento
# freq                       391                     323             15
# mean                       NaN                     NaN            NaN
# std                        NaN                     NaN            NaN
# min                        NaN                     NaN            NaN
# 25%                        NaN                     NaN            NaN
# 50%                        NaN                     NaN            NaN
# 75%                        NaN                     NaN            NaN
# max                        NaN                     NaN            NaN
#
#               Sector            Subsector  \
# count            463                  112
# unique            11                   24
# top     Inmobiliaria  Fondos de inversión
# freq             255                   41
# mean             NaN                  NaN
# std              NaN                  NaN
# min              NaN                  NaN
# 25%              NaN                  NaN
# 50%              NaN                  NaN
# 75%              NaN                  NaN
# max              NaN                  NaN
#
#                                                    Fuente  \
# count                                                 194
# unique                                                169
# top     https://www.encajatualquiler.com/politica-de-p...
# freq                                                   13
# mean                                                  NaN
# std                                                   NaN
# min                                                   NaN
# 25%                                                   NaN
# 50%                                                   NaN
# 75%                                                   NaN
# max                                                   NaN
#
#                                                  Fuente 2  \
# count                                                 103
# unique                                                 88
# top     http://www.fidere-socimi.com/wp-content/upload...
# freq                                                    8
# mean                                                  NaN
# std                                                   NaN
# min                                                   NaN
# 25%                                                   NaN
# 50%                                                   NaN
# 75%                                                   NaN
# max                                                   NaN
#
#                                                  Fuente 3  \
# count                                                  55
# unique                                                 45
# top     https://civio.box.com/s/2kjbkbys11w115aqx2edz8...
# freq                                                    4
# mean                                                  NaN
# std                                                   NaN
# min                                                   NaN
# 25%                                                   NaN
# 50%                                                   NaN
# 75%                                                   NaN
# max                                                   NaN
#
#                                                  Fuente 4  \
# count                                                  39
# unique                                                 33
# top     https://civio.box.com/s/7qqjbmn1yc3o5d7r50kdn5...
# freq                                                    4
# mean                                                  NaN
# std                                                   NaN
# min                                                   NaN
# 25%                                                   NaN
# 50%                                                   NaN
# 75%                                                   NaN
# max                                                   NaN
#
#                                                  Fuente 5  \
# count                                                  28
# unique                                                 22
# top     https://civio.box.com/s/yr183xzwbr6fbydv9bl6qv...
# freq                                                    4
# mean                                                  NaN
# std                                                   NaN
# min                                                   NaN
# 25%                                                   NaN
# 50%                                                   NaN
# 75%                                                   NaN
# max                                                   NaN
#
#                                                  Fuente 6  \
# count                                                  19
# unique                                                 15
# top     https://civio.box.com/s/uotdgk9d65yeq8m365bix2...
# freq                                                    4
# mean                                                  NaN
# std                                                   NaN
# min                                                   NaN
# 25%                                                   NaN
# 50%                                                   NaN
# 75%                                                   NaN
# max                                                   NaN
#
#                                                  Fuente 7  \
# count                                                  10
# unique                                                  7
# top     https://civio.box.com/s/11pbtb9l0izi1dq11vujt4...
# freq                                                    4
# mean                                                  NaN
# std                                                   NaN
# min                                                   NaN
# 25%                                                   NaN
# 50%                                                   NaN
# 75%                                                   NaN
# max                                                   NaN
#
#                                                  Fuente 8
# count                                                   3
# unique                                                  3
# top     https://civio.box.com/s/11pbtb9l0izi1dq11vujt4...
# freq                                                    1
# mean                                                  NaN
# std                                                   NaN
# min                                                   NaN
# 25%                                                   NaN
# 50%                                                   NaN
# 75%                                                   NaN
# max                                                   NaN

# %%
df_gtm.dtypes
# Out:
# NIF                              object
# Filial propietaria directa       object
# Inmuebles                         int64
# Matriz                           object
# Sede empresa matriz              object
# Sociedad intermedia utilizada    object
# Sede sociedad utilizada          object
# Tipo sociedad utilizada          object
# Administración                   object
# Sector                           object
# Subsector                        object
# Fuente                           object
# Fuente 2                         object
# Fuente 3                         object
# Fuente 4                         object
# Fuente 5                         object
# Fuente 6                         object
# Fuente 7                         object
# Fuente 8                         object
# dtype: object

# %% [markdown]
# ## Indexing

# %% [markdown]
# To extract a single column, use the indexing syntax, like you would do with a dictionary:

# %%
df["Name"]

# %% [markdown]
# For anything else (retrieving a slice of columns, slicing both rows and columns), use the `.loc` accessor instead:

# %%
df.loc[10:12,:] # with .loc , the end is included

# %%
df.loc[10:12,"Name":"Age"]
# Out:
#                                Name     Sex   Age
# 10  Sandstrom, Miss. Marguerite Rut  female   4.0
# 11         Bonnell, Miss. Elizabeth  female  58.0
# 12   Saundercock, Mr. William Henry    male  20.0

# %%
df.loc[10:12,["Name","Age","Embarked"]]
# Out:
#                                Name   Age Embarked
# 10  Sandstrom, Miss. Marguerite Rut   4.0        S
# 11         Bonnell, Miss. Elizabeth  58.0        S
# 12   Saundercock, Mr. William Henry  20.0        S

# %%
df.loc[[10,12]]
# Out:
#     PassengerId  Survived  Pclass                             Name     Sex  \
# 10           11         1       3  Sandstrom, Miss. Marguerite Rut  female
# 12           13         0       3   Saundercock, Mr. William Henry    male
#
#      Age  SibSp  Parch     Ticket   Fare Cabin Embarked
# 10   4.0      1      1    PP 9549  16.70    G6        S
# 12  20.0      0      0  A/5. 2151   8.05   NaN        S

# %%
df.loc[10:12,"Age":"Name"] #important
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-1980838725.py in <cell line: 0>()
# ----> 1 df.loc[10:12,"Age":"Name"] #important
#
# NameError: name 'df' is not defined

# %%
stats = df.describe()

# %%
type(stats)
# Out:
# pandas.core.frame.DataFrame

# %%
stats.loc["min":"max"]
# Out:
#      PassengerId  Survived  Pclass     Age  SibSp  Parch      Fare
# min          1.0       0.0     1.0   0.420    0.0    0.0    0.0000
# 25%        223.5       0.0     2.0  20.125    0.0    0.0    7.9104
# 50%        446.0       0.0     3.0  28.000    0.0    0.0   14.4542
# 75%        668.5       1.0     3.0  38.000    1.0    0.0   31.0000
# max        891.0       1.0     3.0  80.000    8.0    6.0  512.3292

# %%
df.loc[df["Fare"] < 50]
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 0              1         0       3                   Braund, Mr. Owen Harris
# 2              3         1       3                    Heikkinen, Miss. Laina
# 4              5         0       3                  Allen, Mr. William Henry
# 5              6         0       3                          Moran, Mr. James
# 7              8         0       3            Palsson, Master. Gosta Leonard
# ..           ...       ...     ...                                       ...
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# 0      male  22.0      1      0         A/5 21171   7.2500   NaN        S
# 2    female  26.0      0      0  STON/O2. 3101282   7.9250   NaN        S
# 4      male  35.0      0      0            373450   8.0500   NaN        S
# 5      male   NaN      0      0            330877   8.4583   NaN        Q
# 7      male   2.0      3      1            349909  21.0750   NaN        S
# ..      ...   ...    ...    ...               ...      ...   ...      ...
# 886    male  27.0      0      0            211536  13.0000   NaN        S
# 887  female  19.0      0      0            112053  30.0000   B42        S
# 888  female   NaN      1      2        W./C. 6607  23.4500   NaN        S
# 889    male  26.0      0      0            111369  30.0000  C148        C
# 890    male  32.0      0      0            370376   7.7500   NaN        Q
#
# [730 rows x 12 columns]

# %%
df["Fare"] < 10 and df["Age"] > 30
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipython-input-3741815946.py in <cell line: 0>()
# ----> 1 df["Fare"] < 10 and df["Age"] > 30
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/generic.py in __nonzero__(self)
#    1575     @final
#    1576     def __nonzero__(self) -> NoReturn:
# -> 1577         raise ValueError(
#    1578             f"The truth value of a {type(self).__name__} is ambiguous. "
#    1579             "Use a.empty, a.bool(), a.item(), a.any() or a.all()."
#
# ValueError: The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().

# %%
(df["Fare"] < 10) & (df["Age"] > 30) #don't type "and" use its alternative bitwise operator
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4       True
#        ...
# 886    False
# 887    False
# 888    False
# 889    False
# 890     True
# Length: 891, dtype: bool

# %%
df.loc[:, "Age":]  # All rows, from the "Age" column to the last one

# %%
df.loc[:5, ["SibSp", "Parch"]]  # Rows up to the one with the index 5 inclusive, columns "SibSp" and "Parch" only

# %%
df.loc[
    [100, 110],  # Rows labeled 100 and 110
    ["Fare", "Cabin"]
]

# %% [markdown]
# Notice that these methods work for _any_ `DataFrame`. For example, the result of `.describe()` is _also_ a `DataFrame`!

# %%
stats = df.describe()
stats

# %%
type(stats)

# %%
stats.loc["min":"max", ["Age", "Pclass"]]

# %% [markdown]
# ## Selection

# %% [markdown]
# Filtering a `DataFrame` according to some condition is also done with the `.loc` accessor. For this, you can leverage the fact that operations between pandas `DataFrame` or `Series` objects and Python scalars are broadcasted automatically. In other words: operations are performed in sequence for all the elements of the pandas object.

# %%
3 > 100  # Returns False

# %%
df["Fare"] > 100  # Returns a Series of boolean values

# %% [markdown]
# Does the previous `Series` contain any `True` value? You can check with the `.any()` method:

# %%
fare_filter = df["Fare"] > 100
fare_filter.any()

# %%
fare_filter.dtype

# %% [markdown]
# You can use this filter or mask inside `.loc` to select a subset of rows:

# %%
df.loc[fare_filter]

# %% [markdown]
# Combining filters requires some care, because the usual boolean Python operators don't work:

# %%
(3 > 100) and (3 < 1_000)

# %%
(df["Fare"] > 100) and (df["Fare"] < 1_000)  # Fails!

# %% [markdown]
# To operate boolean pandas `Series`, you need to use the bitwise operators:
#
# - Bitwise OR `|`
# - Bitwise AND `&`
# - Bitwise NOT `~`

# %%
# Select rows with cases_total between 100 and 1000
fare_filter = (100 < df["Fare"]) & (df["Fare"] < 1_000)
df.loc[fare_filter]

# %%
# Select cases where "icu" is not null, equivalent to
# df.loc[df["icu"].notnull()]
df.loc[~df["Age"].isnull()]

# %% [markdown]
# ## Exercises

# %% [markdown]
# ### 2. Selecting rows and columns
#
# From the `grandes-tenedores-madrid.csv` dataset, select the rows where the column "Inmuebles" is larger than 300 and "Subsector" is not "Fondos de inversión".
#
# Then, keep only the columns "NIF", "Matriz", "Sede empresa matriz", and "Sector".

# %%
df_gtm.loc[(df_gtm["Inmuebles"] > 300) & (df_gtm["Subsector"] != "Fondos de inversión"), ["NIF","Matriz","Sede empresa matriz", "Sector"]]
# Out:
#             NIF                                    Matriz Sede empresa matriz  \
# 1     B09658576                                       Axa             Francia
# 7     Q2801660H                                      Adif              España
# 8     A86212420                                      Aena              España
# 10   Q2840001h                        Comunidad de Madrid              España
# 11    A28221091                                     Agisa              España
# 16    A87085445                               Grupo Ortiz              España
# 22    B81566366                   Alquileres y Gestión SL              España
# 28    A28100915                           Banco Santander              España
# 34    B09658634                                       Axa             Francia
# 41    G28239747                             Guardia Civil              España
# 50    B84855329                                     Azata              España
# 54    A08000143                            Banco Sabadell              España
# 55    A39000013                           Banco Santander              España
# 64    A63106157                                 CaixaBank              España
# 78    B86772837                                 Carrefour             Francia
# 112   A28121309   Construcciones residenciales y sociales              España
# 120   A63379135                                 CaixaBank              España
# 146   A82044173                  El Encinar del Norte SAU              España
# 147   B28360543  El Parque Inmobiliario de Inversiones SL              España
# 149   A82818311                Ayuntamiento de Alcobendas              España
# 152   A83846139                     Ayuntamiento de Rivas              España
# 157   A28740314                    Ayuntamiento de Madrid              España
# 161   A87266359                 SMT Europe Cooperatief UA        Países Bajos
# 163   A28008647  España S.A. Compañía Nacional de Seguros              España
# 222   B02826451                        Grupo Promur 63 SL              España
# 240   B63343172                                 CaixaBank              España
# 242   B67300533                                 CaixaBank              España
# 248   A28315034                   Inmobiliaria Daganzo SA              España
# 253   A28032852                  Inmobiliaria Hispana, SA              España
# 256   A28254399                              Grupo Lozoya              España
# 257   A28316628                               Blismuac SL              España
# 260   B28079192                        Inmobiliaria Sandi              España
# 261   A28241610                                Adenara SL              España
# 295   A28323368               Groupe Générale Immobilière             Francia
# 301   A83787382                                      CBRE      Estados Unidos
# 305   A58032244                                 CaixaBank              España
# 312   A81046039                           Banco Santander              España
# 325   A86977790               Merlin Properties Socimi SA              España
# 328   B84921758                                   Unicaja              España
# 335   B82153263                       Negocios Brimaro SL              España
# 346   A16004665                           Obras y Vías SA              España
# 348   R2800081H    Orden Hospitalaria de San Juan de Dios              España
# 373   A28239523       Promociones Inmobiliarias Calero SL              España
# 377   B86897865                    Promociones Radente SL              España
# 383   B87981999                Property Leases FTS Madrid              España
# 395   B80677099                        Rentur Patrimonial              España
# 415   A86602158                                     Sareb              España
# 421   B66228768                      Tauro Real Estate SL              España
# 427   A78825734       Terrenos, industrias y almacenes SA              España
# 438   B86369915               Unibail-Rodamco-Westfiel SE             Francia
# 448   A87200598                            Value Base LTD              Israel
# 456   B88391370                         Renta Corporación              España
# 457   A87805768                         Renta Corporación              España
#
#                              Sector
# 1                           Seguros
# 7                             Otros
# 8                             Otros
# 10                   Parque público
# 11                     Inmobiliaria
# 16                     Inmobiliaria
# 22                     Inmobiliaria
# 28            Entidades financieras
# 34                          Seguros
# 41                            Otros
# 50                     Inmobiliaria
# 54            Entidades financieras
# 55            Entidades financieras
# 64            Entidades financieras
# 78   Centros comerciales y mercados
# 112                    Inmobiliaria
# 120           Entidades financieras
# 146                    Inmobiliaria
# 147                    Inmobiliaria
# 149                  Parque público
# 152                  Parque público
# 157                  Parque público
# 161                    Inmobiliaria
# 163                         Seguros
# 222                    Construcción
# 240           Entidades financieras
# 242           Entidades financieras
# 248                    Inmobiliaria
# 253                    Inmobiliaria
# 256                    Inmobiliaria
# 257                    Inmobiliaria
# 260                    Inmobiliaria
# 261                    Inmobiliaria
# 295  Centros comerciales y mercados
# 301                    Inmobiliaria
# 305           Entidades financieras
# 312           Entidades financieras
# 325                    Inmobiliaria
# 328           Entidades financieras
# 335                    Inmobiliaria
# 346                    Construcción
# 348            Entidades religiosas
# 373                    Inmobiliaria
# 377                    Inmobiliaria
# 383                    Inmobiliaria
# 395                    Inmobiliaria
# 415           Entidades financieras
# 421                    Inmobiliaria
# 427                    Inmobiliaria
# 438  Centros comerciales y mercados
# 448           Entidades financieras
# 456                    Inmobiliaria
# 457                    Inmobiliaria

# %% [markdown]
# ## 1-dimensional data: pandas `Series`

# %% [markdown]
# Each of the columns of a `DataFrame` is a `Series` object. `Series` are mutable (hence you can add, remove, and replace elements) and homogeneous (all its elements must have the same type). As you will see, `Series` can be indexed by numerical position (like lists) or by label (like dictionaries).
#
# For example, let's create a `Series` from a Python `list`:

# %%
my_list = list(range(10, 15))
my_list

# %%
ser = pd.Series(my_list)
ser

# %%
type(ser)

# %% [markdown]
# `Series` have an important property, the `dtype`, that holds the type of its individual elements. As you can see in the string representation of the `Series`, the `dtype` of `ser` is `int64`, which means that `ser` is a `Series` of integers.

# %%
ser.dtype

# %% [markdown]
# <div class="alert alert-info">The <code>64</code> part in <code>int64</code> alludes to how much memory does pandas use to store those integers, which is fixed to 64 bits. This means that, contrary to Python integers, there is a maximum integer pandas can store in an <code>int64</code>. But you don't need to worry about that now.</div>

# %% [markdown]
# If `pd.Series` receives heterogeneous input, it will cast everything to `object` and the `Series` will be less useful (no numerical operations will be allowed):

# %%
pd.Series([True, True, False])  # dtype: bool

# %%
pd.Series([True, True, False, 2])  # dtype: object

# %% [markdown]
# `Series` objects have a large number of methods, including some typical statistical and aggregation ones:

# %%
ser.max(), ser.min()

# %%
ser.mean(), ser.median(), ser.std()

# %% [markdown]
# And some more sophisticated methods:

# %%
ser.describe()
# ser.describe([.33, .66, .99])  # notice that you can specify the percentiles!

# %% [markdown]
# Series made of non-numerical dtypes will have a different result for `.describe()`:

# %%
pd.Series([1, 2, 2, 2, 3.0, "five"]).describe()

# %% [markdown]
# A `Series` has some `values` and an `index`. The `index` will become very important when working with `DataFrame`s.

# %%
ser

# %%
ser.values

# %%
ser.index

# %% [markdown]
# `Series` objects can also be created from dictionaries, in which case the index will change:

# %%
pd.Series({"a": 1, "b": 2})

# %% [markdown]
# You can refer to values by index using the `.loc` accessor:

# %%
ser.loc[0]

# %% [markdown]
# <div class="alert alert-warning">Notice that we don't call <code>loc</code> a <em>method</em> because it is not called! It is a special object that "abuses" the indexing/slicing syntax. If you call it with parenthesis, you will get an error.</div>

# %% [markdown]
# The semantics of `.loc` with respect to slicing are slightly different from the base ones from Python. Most importantly, the end of the slice is included!

# %%
ser.loc[1:3]

# %% [markdown]
# To access items by numerical position instead, use `.iloc`:

# %%
ser2 = pd.Series({"a": 1, "b": 2})
ser2

# %%
ser2.loc["a"]

# %%
ser2.loc["b"]

# %%
ser2.iloc[0]

# %%
ser2.iloc[1]

# %% [markdown]
# ## Exercises

# %% [markdown]
# ### 3. Advanced: Managing semi-structured data
#
# Load the `rick-and-morty.json` data to a Python object, then store the episodes list in a variable `episodes`, then pass it to the method `pandas.DataFrame.from_records` to turn the list of episodes into a `DataFrame`.
#
# Then, answer the same questions from session 6, using exclusively pandas methods (no comprehensions or loops).

# %%
import requests

DATA_URL = (
    "https://github.com/astrojuanlu/ie-mbd-python-data-analysis-i/"
    "raw/main/data/rick-and-morty.json"
)

data = requests.get(DATA_URL).json()
print(type(data), len(data))

# %%
df = pd.DataFrame.from_records(data["_embedded"]["episodes"])
df.head()
